# %% [markdown]
# <a href="https://colab.research.google.com/github/PrashantSBasnet/SSD_TBC/blob/develop/GrowthFunctions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate values for n
n_values = np.linspace(1, 10, 100)  # You can adjust the range and number of points as needed

# Calculate function values for each value of n
log_n_values = np.log(n_values)
n_log_n_values = n_values * np.log(n_values)
n_values_linear = n_values
constant_values = np.ones_like(n_values)
n_squared_values = n_values**2
n_cubed_values = n_values**3

# Plot the results
plt.figure(figsize=(10, 6))

#plt.plot(n_values, log_n_values, label='log(n)')
#plt.plot(n_values, n_log_n_values, label='n log(n)')
#plt.plot(n_values, n_values_linear, label='n')
#plt.plot(n_values, constant_values, label='1')
#plt.plot(n_values, n_squared_values, label='n^2')
#plt.plot(n_values, n_cubed_values, label='n^3')

plt.title('Comparing Growth Functions')
plt.xlabel('Input size n')
plt.ylabel('Time')
plt.legend()
plt.grid(True)
plt.show()
